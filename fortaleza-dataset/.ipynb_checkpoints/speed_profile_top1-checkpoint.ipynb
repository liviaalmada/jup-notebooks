# %%
from scipy import stats
from scipy.stats import norm
import numpy as np
import speed_db as db
from importlib import reload

# %%
reload(db)
edge1 = db.access("taxi-fortaleza", "postgres", "73561", "0")

# %%
edge2 = db.access("taxi-fortaleza", "postgres", "73521", "0")

# %%
edge3 = db.access("taxi-fortaleza", "postgres", "86528", "0")

# %%
edge4 = db.access("taxi-fortaleza", "postgres", "86868", "0")

# %%
edge5 = db.access("taxi-fortaleza", "postgres", "72759", "0")

# %%
edge1
# Out:
#        traj_id   edge                date      speed  week_day
# 0    982347659  73561 2016-06-05 20:43:09  22.227774         0
# 1    982347659  73561 2016-06-05 20:39:03  22.227774         0
# 2    982347659  73561 2016-06-05 20:43:09  22.227774         0
# 3    982347659  73561 2016-06-05 20:43:09  22.227774         0
# 4    982347659  73561 2016-06-05 20:43:09  22.227774         0
# 5    982347659  73561 2016-06-05 20:43:09  22.227774         0
# 6    982347164  73561 2016-06-05 00:10:55  49.653785         0
# 7    982347164  73561 2016-06-05 00:12:45  49.653785         0
# 8    982347164  73561 2016-06-05 00:12:45  49.653785         0
# 9    982347164  73561 2016-06-05 00:12:45  49.653785         0
# 10   982347164  73561 2016-06-05 00:12:45  49.653785         0
# 11   982347164  73561 2016-06-05 00:12:45  49.653785         0
# 12   982347164  73561 2016-06-05 00:12:45  49.653785         0
# 13   982347164  73561 2016-06-05 00:12:45  49.653785         0
# ...
